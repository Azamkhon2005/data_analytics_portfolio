# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')

# %%
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#31
'''Write a Pandas program to count how many times each value in cut series of diamonds DataFrame occurs'''
data['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
#32
'''Write a Pandas program to display percentages of each value of cut series occurs in diamonds DataFrame'''
data['cut'].value_counts(normalize=True)
# Out:
# Ideal        0.399537
# Premium      0.255673
# Very Good    0.223990
# Good         0.090953
# Fair         0.029848
# Name: cut, dtype: float64

# %%
#33
'''Write a Pandas program to display the unique values in cut series of diamonds DataFrame'''
data['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
#34
'''Write a Pandas program to display the unique values in cut series of diamonds DataFrame'''
data['cut'].nunique()
# Out:
# 5

# %%
#35
''' Write a Pandas program to compute a cross-tabulation of two Series in diamonds DataFrame'''
pd.crosstab(data['cut'],data['price'])
# Out:
# price      326    327    334    335    336    337    338    339    340    \
# cut
# Fair           0      0      0      0      0      1      0      0      0
# Good           0      1      0      1      0      0      0      1      0
# Ideal          1      0      0      0      0      0      0      0      1
# Premium        1      0      1      0      0      0      0      0      0
# Very Good      0      0      0      0      2      1      1      0      0
#
# price      342    ...  18787  18788  18791  18795  18797  18803  18804  18806  \
# cut               ...
# Fair           0  ...      0      0      0      0      0      0      0      0
# Good           0  ...      0      1      0      0      0      0      0      0
# Ideal          0  ...      1      0      1      0      0      0      1      1
# Premium        1  ...      0      0      1      2      1      0      0      0
# Very Good      0  ...      0      0      0      0      0      1      0      0
#
# price      18818  18823
# ...

# %%
#36
'''Write a Pandas program to calculate various summary statistics of cut series of diamonds DataFrame'''
data['carat'].describe()
# Out:
# count    53940.000000
# mean         0.797940
# std          0.474011
# min          0.200000
# 25%          0.400000
# 50%          0.700000
# 75%          1.040000
# max          5.010000
# Name: carat, dtype: float64

# %%
#37
'''Write a Pandas program to create a histogram of the 'carat' Series  of diamonds DataFrame'''
data['carat'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
#38
'''Write a Pandas program to create a bar plot of the 'value_counts' for the 'cut' series'''
data['cut'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#39
'''Write a Pandas program to create a DataFrame of booleans (True if missing, False if not missing)'''
data.isnull()
# Out:
#        carat    cut  color  clarity  depth  table  price      x      y      z
# 0      False  False  False    False  False  False  False  False  False  False
# 1      False  False  False    False  False  False  False  False  False  False
# 2      False  False  False    False  False  False  False  False  False  False
# 3      False  False  False    False  False  False  False  False  False  False
# 4      False  False  False    False  False  False  False  False  False  False
# ...      ...    ...    ...      ...    ...    ...    ...    ...    ...    ...
# 53935  False  False  False    False  False  False  False  False  False  False
# 53936  False  False  False    False  False  False  False  False  False  False
# 53937  False  False  False    False  False  False  False  False  False  False
# 53938  False  False  False    False  False  False  False  False  False  False
# 53939  False  False  False    False  False  False  False  False  False  False
#
# [53940 rows x 10 columns]

# %%
#40
'''Write a Pandas program to count the number of missing values in each Series of diamonds DataFrame'''
data.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
#41
'''Write a Pandas program to check the number of rows and columns and
drop those row if 'any' values are missing in a row'''
data.shape
data.dropna(how='any').shape
# Out:
# (53940, 10)

# %%
#42
'''Write a Pandas program to drop a row if any or all values in a row are missing of 
diamonds DataFrame on two specific columns.'''
print(data.dropna(subset=['cut','price'],how='any').shape)
print(data.dropna(subset=['cut','price'],how='all').shape)
# Out:
# (53940, 10)
# (53940, 10)

# %%
#43
'''Write a Pandas program to set an existing column as the index of diamonds DataFrame'''
data.set_index('color')
# Out:
#        carat        cut clarity  depth  table  price     x     y     z
# color
# E       0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# E       0.21    Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# E       0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# I       0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# J       0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...     ...    ...    ...    ...   ...   ...   ...
# D       0.72      Ideal     SI1   60.8   57.0   2757  5.75  5.76  3.50
# D       0.72       Good     SI1   63.1   55.0   2757  5.69  5.75  3.61
# D       0.70  Very Good     SI1   62.8   60.0   2757  5.66  5.68  3.56
# H       0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12  3.74
# D       0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
#44
'''Write a Pandas program to set an existing column as
the index of diamonds DataFrame and restore the index name,and move the index back to a column'''
data.set_index('color',inplace=True)
data.reset_index(inplace=True)
data.head()
# Out:
#   color  carat      cut clarity  depth  table  price     x     y     z
# 0     E   0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     E   0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     E   0.23     Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29  Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     J   0.31     Good     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#49
'''Write a Pandas program to read specified rows and all columns of diamonds DataFrame.'''
data.iloc[3:6,1]
# Out:
# 3    0.29
# 4    0.31
# 5    0.24
# Name: carat, dtype: float64

# %%
#50
'''Write a Pandas program to read rows 0, 5, 7 and all columns of diamonds DataFrame.'''
data.loc[[0,5,7]]
# Out:
#   color  carat        cut clarity  depth  table  price     x     y     z
# 0     E   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 5     J   0.24  Very Good    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7     H   0.26  Very Good     SI1   61.9   55.0    337  4.07  4.11  2.53

# %%
#51
'''Write a Pandas program to read rows 2 through 5 and all columns of diamonds DataFrame'''
data.loc[2:5]
# Out:
#   color  carat        cut clarity  depth  table  price     x     y     z
# 2     E   0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     J   0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5     J   0.24  Very Good    VVS2   62.8   57.0    336  3.94  3.96  2.48

# %%
#52
'''Write a Pandas program to read rows 0 through 2 (inclusive), columns color and price '''
data.loc[[0,2],['color','price']]
# Out:
#   color  price
# 0     E    326
# 2     E    327

# %%
#53
''' Write a Pandas program to read rows 0 through 2 (inclusive), columns color through price (inclusive)'''
data.loc[[0,2],'color':'price']
# Out:
#   color  carat    cut clarity  depth  table  price
# 0     E   0.23  Ideal     SI2   61.5   55.0    326
# 2     E   0.23   Good     VS1   56.9   65.0    327

# %%
#54
''' Write a Pandas program to read rows in which the 'cut' is 'Premium', column 'color' '''
data[data['cut']=='Premium']['color']
# Out:
# 1        E
# 3        I
# 12       F
# 14       E
# 15       E
#         ..
# 53928    E
# 53930    E
# 53931    F
# 53934    D
# 53938    H
# Name: color, Length: 13791, dtype: object

# %%
#55
''' Write a Pandas program to read rows in positions 0 and 1,
columns in positions 0 and 3 of diamonds DataFrame '''
data.iloc[[0,1],[0,3]]
# Out:
#   color clarity
# 0     E     SI2
# 1     E     SI1

# %%
#56
'''Write a Pandas program to read rows in positions 0 through 4, columns in positions 1 through 4'''
data.iloc[0:4,1:4]
# Out:
#    carat      cut clarity
# 0   0.23    Ideal     SI2
# 1   0.21  Premium     SI1
# 2   0.23     Good     VS1
# 3   0.29  Premium     VS2

# %%
#57
'''Write a Pandas program to read rows in positions 0 through 4 (exclusive) and all columns'''
data.iloc[0:5]
# Out:
#   color  carat      cut clarity  depth  table  price     x     y     z
# 0     E   0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     E   0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     E   0.23     Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29  Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     J   0.31     Good     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#58
'''Write a Pandas program to read rows 2 through 5, columns in positions 0 through 2'''
data.iloc[2:5,0:2]
# Out:
#   color  carat
# 2     E   0.23
# 3     I   0.29
# 4     J   0.31

# %%
#59
'''Write a Pandas program to print a concise summary of diamonds DataFrame.'''
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   color    53940 non-null  object
#  1   carat    53940 non-null  float64
#  2   cut      53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
#60
''' Write a Pandas program to get the true memory usage by diamonds DataFrame.'''
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   color    53940 non-null  object
#  1   carat    53940 non-null  float64
#  2   cut      53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 12.2 MB

# %%
#61
'''Write a Pandas program to calculate the memory usage for each Series (in bytes)'''
data.memory_usage(deep='True')
# Out:
# Index          128
# color      3128520
# carat       431520
# cut        3413674
# clarity    3242590
# depth       431520
# table       431520
# price       431520
# x           431520
# y           431520
# z           431520
# dtype: int64

# %%
#62
'''Write a Pandas program to get randomly sample rows from diamonds DataFrame'''
data.sample(frac = 0.2)
# Out:
#       color  carat        cut clarity  depth  table  price     x     y     z
# 13490     G   1.15  Very Good     SI1   61.3   62.0   5538  6.68  6.72  4.11
# 40045     E   0.54       Good     SI2   63.9   54.0   1112  5.18  5.12  3.29
# 7059      I   0.33    Premium    VVS2   61.0   58.0    579  4.42  4.46  2.71
# 25063     I   1.83  Very Good     VS1   61.9   57.0  13587  7.85  7.91  4.88
# 38625     H   0.31      Ideal     VS2   62.2   53.0    489  4.38  4.43  2.74
# ...     ...    ...        ...     ...    ...    ...    ...   ...   ...   ...
# 33544     D   0.35      Ideal     VS2   62.0   55.0    829  4.47  4.53  2.79
# 14578     E   1.21  Very Good     SI1   61.0   60.0   5885  6.83  6.88  4.18
# 16650     F   1.02  Very Good     VS2   63.2   57.0   6659  6.34  6.41  4.03
# 4882      D   0.71      Ideal     VS1   60.9   58.0   3716  5.72  5.78  3.50
# 51298     F   0.70  Very Good     VS2   61.0   59.0   2362  5.69  5.75  3.49
#
# [10788 rows x 10 columns]

# %%
#63
'''Write a Pandas program to get sample 75% of the diamonds DataFrame's rows 
without replacement and store the remaining 25% of the rows'''
sample = data.sample(frac=0.75)
data[~ data.isin(sample)].dropna()
# Out:
#       color  carat        cut clarity  depth  table   price     x     y     z
# 0         E   0.23      Ideal     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 2         E   0.23       Good     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3         I   0.29    Premium     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 18        J   0.30       Good     SI1   63.8   56.0   351.0  4.23  4.26  2.71
# 27        J   0.30  Very Good     VS2   62.2   57.0   357.0  4.28  4.30  2.67
# ...     ...    ...        ...     ...    ...    ...     ...   ...   ...   ...
# 53923     I   0.73      Ideal     VS2   61.3   56.0  2756.0  5.80  5.84  3.57
# 53926     E   0.71      Ideal     SI1   61.9   56.0  2756.0  5.71  5.73  3.54
# 53927     F   0.79       Good     SI1   58.1   59.0  2756.0  6.06  6.13  3.54
# 53929     G   0.71      Ideal     VS1   61.4   56.0  2756.0  5.76  5.73  3.53
# 53936     D   0.72       Good     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
#
# [13485 rows x 10 columns]

# %%
#64
''' Write a Pandas program to read the diamonds DataFrame and detect duplicate color.'''
data.duplicated(subset='color')
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 53935     True
# 53936     True
# 53937     True
# 53938     True
# 53939     True
# Length: 53940, dtype: bool

# %%
#65
'''Write a Pandas program to count the duplicate rows of diamonds DataFrame.'''
data.duplicated().sum()
# Out:
# 146
