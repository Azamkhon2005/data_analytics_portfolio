# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r'world_alcohol.csv')
df.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
#1
'''Write a Pandas program to display the dimensions or shape of the World alcohol consumption dataset.
Also extract the column names from the dataset.'''
print('shape of dataset:',df.shape)
print('columns names:',df.columns)
# Out:
# shape of dataset: (100, 5)
# columns names: Index(['Year', 'WHO region', 'Country', 'Beverage Types', 'Display Value'], dtype='object')

# %%
#2
'''Write a Pandas program to select first 2 rows, 2 columns
and specific two columns from World alcohol consumption dataset'''
df.loc[:1,['Year','WHO region']]
# Out:
#    Year       WHO region
# 0  1986  Western Pacific
# 1  1986         Americas

# %%
df[['Year','WHO region']]
# Out:
#     Year       WHO region
# 0   1986  Western Pacific
# 1   1986         Americas
# 2   1985           Africa
# 3   1986         Americas
# 4   1987         Americas
# ..   ...              ...
# 95  1984           Africa
# 96  1985           Europe
# 97  1984  South-East Asia
# 98  1984           Africa
# 99  1985  South-East Asia
#
# [100 rows x 2 columns]

# %%
#3
'''Write a Pandas program to select random number of rows, 
fraction of random rows from World alcohol consumption dataset'''
df.loc[list(np.random.randint(0,100,10))]
# Out:
#     Year             WHO region                           Country  \
# 82  1987                 Europe                           Ireland
# 37  1986                 Europe                            Sweden
# 24  1985                 Africa                           Comoros
# 84  1986        South-East Asia                         Sri Lanka
# 74  1986               Americas  Bolivia (Plurinational State of)
# 66  1987  Eastern Mediterranean                              Iraq
# 6   1987                 Africa                         Mauritius
# 16  1984               Americas                        Costa Rica
# 64  1989               Americas  Bolivia (Plurinational State of)
# 29  1986                 Europe                             Italy
#
#    Beverage Types  Display Value
# 82        Spirits           2.25
# 37           Beer           3.04
# 24          Other            NaN
# 84          Other           0.00
# 74        Spirits           2.06
# 66           Wine           0.01
# ...

# %%
df.sample(10)
# Out:
#     Year             WHO region               Country Beverage Types  \
# 3   1986               Americas              Colombia           Beer
# 18  1984                 Europe                Norway        Spirits
# 91  1989                 Europe              Bulgaria           Beer
# 56  1987        Western Pacific              Viet Nam           Wine
# 59  1989  Eastern Mediterranean  Syrian Arab Republic          Other
# 69  1986                 Africa                  Togo        Spirits
# 93  1987                 Africa            Madagascar          Other
# 87  1989  Eastern Mediterranean                  Iraq           Wine
# 20  1986        South-East Asia               Myanmar           Wine
# 70  1986                 Africa            Madagascar        Spirits
#
#     Display Value
# 3            4.27
# 18           1.62
# 91           4.43
# 56           0.00
# 59           0.00
# 69           0.42
# 93            NaN
# 87           0.01
# 20           0.00
# ...

# %%
#4
'''Write a Pandas program to find and drop the missing values from World alcohol consumption dataset'''
print(df[df.isna().any(axis=1)])
print('count of missing values:')
print(df.isnull().sum())
df = df.dropna()
# Out:
# Empty DataFrame
# Columns: [Year, WHO region, Country, Beverage Types, Display Value]
# Index: []
# count of missing values:
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     0
# dtype: int64

# %%
#5
'''Write a Pandas program to remove the duplicates from 
'WHO region' column of World alcohol consumption dataset'''
df.drop_duplicates(subset='WHO region')
# Out:
#     Year             WHO region       Country Beverage Types  Display Value
# 0   1986        Western Pacific      Viet Nam           Wine           0.00
# 1   1986               Americas       Uruguay          Other           0.50
# 2   1985                 Africa  Cte d'Ivoire           Wine           1.62
# 13  1984  Eastern Mediterranean   Afghanistan          Other           0.00
# 18  1984                 Europe        Norway        Spirits           1.62
# 20  1986        South-East Asia       Myanmar           Wine           0.00

# %%
#6
'''Write a Pandas program to find out the alcohol consumption
of a given year from the world alcohol consumption dataset'''
year = int(input('enter the year:'))
df[df.Year == year]
# Out:
# enter the year:1986
#     Year             WHO region                           Country  \
# 0   1986        Western Pacific                          Viet Nam
# 1   1986               Americas                           Uruguay
# 3   1986               Americas                          Colombia
# 8   1986               Americas               Antigua and Barbuda
# 20  1986        South-East Asia                           Myanmar
# 30  1986                 Africa                      Sierra Leone
# 31  1986        Western Pacific  Micronesia (Federated States of)
# 34  1986                 Europe                Russian Federation
# 37  1986                 Europe                            Sweden
# 41  1986                 Europe                    Czech Republic
# 47  1986               Americas                            Mexico
# 49  1986                 Europe                             Malta
# 52  1986  Eastern Mediterranean                      Saudi Arabia
# ...

# %%
#7
'''Write a Pandas program to find out the alcohol consumption details in the year '1987' or '1989'
from the world alcohol consumption dataset.'''
df[(df.Year==1987) | (df.Year==1989)]
# Out:
#     Year             WHO region                           Country  \
# 4   1987               Americas             Saint Kitts and Nevis
# 5   1987               Americas                         Guatemala
# 6   1987                 Africa                         Mauritius
# 10  1987                 Africa                          Botswana
# 11  1989               Americas                         Guatemala
# 15  1987                 Africa                     Guinea-Bissau
# 17  1989                 Africa                        Seychelles
# 21  1989               Americas                        Costa Rica
# 28  1987        Western Pacific                          Viet Nam
# 32  1989                 Africa                         Mauritius
# 36  1987  Eastern Mediterranean                             Egypt
# 38  1987  Eastern Mediterranean                             Qatar
# 39  1987                 Africa                      Burkina Faso
# ...

# %%
#8
'''Write a Pandas program to find out the alcohol consumption details 
by the 'Americas' in the year '1985'  from the world alcohol consumption dataset'''
df[(df['WHO region']=='Americas') & (df['Year']==1985)]
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 35  1985   Americas  Saint Kitts and Nevis        Spirits           2.24

# %%
#9
'''Write a Pandas program to find out the alcohol consumption details
in the year '1986' where WHO region is 'Western Pacific' and country is 'VietNam' from df'''
df[(df['Year']==1986) & (df['WHO region']=='Western Pacific') & df['Country']=='Viet Nam']
# Out:
# Empty DataFrame
# Columns: [Year, WHO region, Country, Beverage Types, Display Value]
# Index: []

# %%
#10
'''Write a Pandas program to find out the alcohol consumption details in the year '1986' or '1989' 
where WHO region is 'Americas' from the world alcohol consumption dataset.'''
df[((df['Year']==1986) | (df['Year']==1989))  & (df['WHO region']=='Americas')]
# Out:
#     Year WHO region                           Country Beverage Types  \
# 1   1986   Americas                           Uruguay          Other
# 3   1986   Americas                          Colombia           Beer
# 8   1986   Americas               Antigua and Barbuda        Spirits
# 11  1989   Americas                         Guatemala           Beer
# 21  1989   Americas                        Costa Rica        Spirits
# 47  1986   Americas                            Mexico          Other
# 55  1989   Americas                          Suriname           Wine
# 64  1989   Americas  Bolivia (Plurinational State of)           Beer
# 74  1986   Americas  Bolivia (Plurinational State of)        Spirits
# 78  1989   Americas                           Jamaica          Other
# 86  1986   Americas                           Bahamas           Wine
#
#     Display Value
# 1            0.50
# 3            4.27
# 8            1.55
# 11           0.62
# 21           4.51
# 47           0.04
# ...

# %%
#11
''' Write a Pandas program to find out the alcohol consumption details in the year '1986' or '1989' 
where WHO region is 'Americas' or 'Europe' from the world alcohol consumption dataset.'''
df[((df['Year']==1986) | (df['Year']==1989)) & ((df['WHO region']=='Americas') | (df['WHO region']=='Europe'))]
# Out:
#     Year WHO region                           Country Beverage Types  \
# 1   1986   Americas                           Uruguay          Other
# 3   1986   Americas                          Colombia           Beer
# 8   1986   Americas               Antigua and Barbuda        Spirits
# 11  1989   Americas                         Guatemala           Beer
# 21  1989   Americas                        Costa Rica        Spirits
# 34  1986     Europe                Russian Federation           Wine
# 37  1986     Europe                            Sweden           Beer
# 41  1986     Europe                    Czech Republic           Beer
# 47  1986   Americas                            Mexico          Other
# 49  1986     Europe                             Malta           Wine
# 55  1989   Americas                          Suriname           Wine
# 57  1989     Europe                           Croatia           Wine
# 64  1989   Americas  Bolivia (Plurinational State of)           Beer
# ...

# %%
#12
'''Write a Pandas program to find out the 'WHO region, 'Country', 'Beverage Types' 
in the year '1986' or '1989' where WHO region is 'Americas' or 'Europe' from df'''
df[((df['Year']==1986) | (df['Year']==1989)) & ((df['WHO region']=='Americas') | (df['WHO region']=='Europe'))][['WHO region','Country','Beverage Types']]
# Out:
#    WHO region                           Country Beverage Types
# 1    Americas                           Uruguay          Other
# 3    Americas                          Colombia           Beer
# 8    Americas               Antigua and Barbuda        Spirits
# 11   Americas                         Guatemala           Beer
# 21   Americas                        Costa Rica        Spirits
# 34     Europe                Russian Federation           Wine
# 37     Europe                            Sweden           Beer
# 41     Europe                    Czech Republic           Beer
# 47   Americas                            Mexico          Other
# 49     Europe                             Malta           Wine
# 55   Americas                          Suriname           Wine
# 57     Europe                           Croatia           Wine
# 64   Americas  Bolivia (Plurinational State of)           Beer
# 74   Americas  Bolivia (Plurinational State of)        Spirits
# ...

# %%
#13
'''Write a Pandas program to find out the records where consumption of beverages per person average >=5 
and Beverage Types is Beer from world alcohol consumption dataset.'''
df[(df['Display Value']>=5) & (df['Beverage Types']=='Beer')]
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 41  1986     Europe  Czech Republic           Beer           6.82

# %%
#14
'''Write a Pandas program to find out the records where consumption of beverages per person average >=4 
and Beverage Types is Beer, Wine, Spirits from world alcohol consumption dataset'''
df[(df['Display Value']>=5) & ((df['Beverage Types']=='Beer') | (df['Beverage Types']=='Wine') | (df['Beverage Types']=='Spirits'))]
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 41  1986     Europe  Czech Republic           Beer           6.82
# 57  1989     Europe         Croatia           Wine           5.10
# 96  1985     Europe      Luxembourg           Wine           7.38

# %%
#15
'''Write a Pandas program to filter the specified columns and records by  range from df'''
df.loc[:5,['Year','Display Value']]
# Out:
#    Year  Display Value
# 0  1986           0.00
# 1  1986           0.50
# 2  1985           1.62
# 3  1986           4.27
# 4  1987           1.98
# 5  1987           0.00
